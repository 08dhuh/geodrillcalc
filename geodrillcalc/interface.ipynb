# %%
depth_data = {
    "aquifer_layer": [
        "QA_UTQA",
        "UTQD",
        "UTAF",
        "UTD",
        "UMTA",
        "UMTD",
        "LMTA",
        "LTA",
        "BSE"
    ],
    "is_aquifer": [
        True,
        False,
        True,
        False,
        True,
        False,
        True,
        True,
        False
    ],
    "depth_to_base": [
        3,
        53,
        112,
        150,
        150,
        1000,
        1000,
        1221,
        1421
    ]
}

#depth = pd.DataFrame(depth_data)
input_data = {
    "required_flow_rate": 4320,
    "hydraulic_conductivity": 5,
    "average_porosity": 0.25,
    "bore_lifetime_year": 30,
    "groundwater_depth": 25,
    "long_term_decline_rate": 1,
    "allowable_drawdown": 25,
    "safety_margin": 25
}

initial_input = (depth_data, input_data)

# %%
from geodrillcalc_interface import GeoDrillCalcInterface

gdi = GeoDrillCalcInterface()
gdi.calculate_and_return_wellbore_parameters(True, depth_data, input_data)
# Out:
# 18:43:17 15-11-2023 INFO superficial_casing_required: False
# 18:43:17 15-11-2023 INFO separate_pump_chamber_required: True
# 18:43:17 15-11-2023 INFO production_screen_length: 69.7420951749512
# 18:43:17 15-11-2023 INFO injection_screen_length: 139.4841903499024
# 18:43:17 15-11-2023 INFO production_screen_length_error: (62.767885657456084, 76.71630469244633)
# 18:43:17 15-11-2023 INFO injection_screen_length_error: (125.53577131491217, 153.43260938489266)
# 18:43:17 15-11-2023 INFO min_total_casing_production_screen_diameter: 0.1397
# 18:43:17 15-11-2023 INFO production_screen_diameter: 0.1397
# 18:43:17 15-11-2023 INFO injection_screen_diameter: 0.1016
# 18:43:17 15-11-2023 INFO production_open_hole_diameter: 0.1905
# 18:43:17 15-11-2023 INFO injection_open_hole_diameter: 0.1905
# 18:43:17 15-11-2023 INFO pump_inlet_depth: 105
# 18:43:17 15-11-2023 INFO minimum_pump_housing_diameter: 0.28587049479391613
# ...
